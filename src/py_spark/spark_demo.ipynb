# %%
from pyspark.sql import SparkSession
spark= SparkSession.builder.appName("demo").getOrCreate()
from pyspark.sql.types import StructType,StructField, StringType, IntegerType
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pyspark.sql import SparkSession
#       2 spark= SparkSession.builder.appName("demo").getOrCreate()
#       3 from pyspark.sql.types import StructType,StructField, StringType, IntegerType
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/__init__.py:51
#      48 import types
#      50 from pyspark.conf import SparkConf
# ---> 51 from pyspark.context import SparkContext
#      52 from pyspark.rdd import RDD, RDDBarrier
#      53 from pyspark.files import SparkFiles
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/context.py:30
#      27 from py4j.protocol import Py4JError
#      28 from py4j.java_gateway import is_instance_of
# ---> 30 from pyspark import accumulators
#      31 from pyspark.accumulators import Accumulator
#      32 from pyspark.broadcast import Broadcast, BroadcastPickleRegistry
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/accumulators.py:97
#      95     import socketserver as SocketServer
#      96 import threading
# ---> 97 from pyspark.serializers import read_int, PickleSerializer
#     100 __all__ = ['Accumulator', 'AccumulatorParam']
#     103 pickleSer = PickleSerializer()
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/serializers.py:71
#      68     xrange = range
#      69 pickle_protocol = pickle.HIGHEST_PROTOCOL
# ---> 71 from pyspark import cloudpickle
#      72 from pyspark.util import _exception_message, print_exec
#      75 __all__ = ["PickleSerializer", "MarshalSerializer", "UTF8Deserializer"]
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/cloudpickle.py:209
#     190         else:
#     191             return types.CodeType(
#     192                 co.co_argcount,
#     193                 co.co_kwonlyargcount,
#    (...)    206                 (),
#     207             )
# --> 209 _cell_set_template_code = _make_cell_set_template_code()
#     212 def cell_set(cell, value):
#     213     """Set the value of a closure cell.
#     214     """
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/cloudpickle.py:172, in _make_cell_set_template_code()
#     170 else:
#     171     if hasattr(types.CodeType, "co_posonlyargcount"):  # pragma: no branch
# --> 172         return types.CodeType(
#     173             co.co_argcount,
#     174             co.co_posonlyargcount,  # Python3.8 with PEP570
#     175             co.co_kwonlyargcount,
#     176             co.co_nlocals,
#     177             co.co_stacksize,
#     178             co.co_flags,
#     179             co.co_code,
#     180             co.co_consts,
#     181             co.co_names,
#     182             co.co_varnames,
#     183             co.co_filename,
#     184             co.co_name,
#     185             co.co_firstlineno,
#     186             co.co_lnotab,
#     187             co.co_cellvars,  # this is the trickery
#     188             (),
#     189         )
#     190     else:
#     191         return types.CodeType(
#     192             co.co_argcount,
#     193             co.co_kwonlyargcount,
#    (...)    206             (),
#     207         )
#
# TypeError: code() argument 13 must be str, not int

# %%
person_list = [("Berry","","Allen",1,"M"),
        ("Oliver","Queen","",2,"M"),
        ("Robert","","Williams",3,"M"),
        ("Tony","","Stark",4,"F"),
        ("Rajiv","Mary","Kumar",5,"F")
]

schema = StructType([ \
        StructField("firstname",StringType(),True), \
        StructField("middlename",StringType(),True), \
        StructField("lastname",StringType(),True), \
        StructField("id", IntegerType(), True), \
        StructField("gender", StringType(), True), \
 ])

df = spark.createDataFrame(data=person_list,schema=schema)

df.show(truncate=False)

df.printSchema()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyspark.sql.types import StructType,StructField, StringType, IntegerType
#       3 person_list = [("Berry","","Allen",1,"M"),
#       4         ("Oliver","Queen","",2,"M"),
#       5         ("Robert","","Williams",3,"M"),
#       6         ("Tony","","Stark",4,"F"),
#       7         ("Rajiv","Mary","Kumar",5,"F")
#       8 ]
#      10 schema = StructType([ \
#      11         StructField("firstname",StringType(),True), \
#      12         StructField("middlename",StringType(),True), \
#    (...)     15         StructField("gender", StringType(), True), \
#      16  ])
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/__init__.py:51
#      48 import types
#      50 from pyspark.conf import SparkConf
# ---> 51 from pyspark.context import SparkContext
#      52 from pyspark.rdd import RDD, RDDBarrier
#      53 from pyspark.files import SparkFiles
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/context.py:30
#      27 from py4j.protocol import Py4JError
#      28 from py4j.java_gateway import is_instance_of
# ---> 30 from pyspark import accumulators
#      31 from pyspark.accumulators import Accumulator
#      32 from pyspark.broadcast import Broadcast, BroadcastPickleRegistry
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/accumulators.py:97
#      95     import socketserver as SocketServer
#      96 import threading
# ---> 97 from pyspark.serializers import read_int, PickleSerializer
#     100 __all__ = ['Accumulator', 'AccumulatorParam']
#     103 pickleSer = PickleSerializer()
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/serializers.py:71
#      68     xrange = range
#      69 pickle_protocol = pickle.HIGHEST_PROTOCOL
# ---> 71 from pyspark import cloudpickle
#      72 from pyspark.util import _exception_message, print_exec
#      75 __all__ = ["PickleSerializer", "MarshalSerializer", "UTF8Deserializer"]
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/cloudpickle.py:209
#     190         else:
#     191             return types.CodeType(
#     192                 co.co_argcount,
#     193                 co.co_kwonlyargcount,
#    (...)    206                 (),
#     207             )
# --> 209 _cell_set_template_code = _make_cell_set_template_code()
#     212 def cell_set(cell, value):
#     213     """Set the value of a closure cell.
#     214     """
#
# File ~/Documents/GitHub/PythonRepo/.venv/lib/python3.12/site-packages/pyspark/cloudpickle.py:172, in _make_cell_set_template_code()
#     170 else:
#     171     if hasattr(types.CodeType, "co_posonlyargcount"):  # pragma: no branch
# --> 172         return types.CodeType(
#     173             co.co_argcount,
#     174             co.co_posonlyargcount,  # Python3.8 with PEP570
#     175             co.co_kwonlyargcount,
#     176             co.co_nlocals,
#     177             co.co_stacksize,
#     178             co.co_flags,
#     179             co.co_code,
#     180             co.co_consts,
#     181             co.co_names,
#     182             co.co_varnames,
#     183             co.co_filename,
#     184             co.co_name,
#     185             co.co_firstlineno,
#     186             co.co_lnotab,
#     187             co.co_cellvars,  # this is the trickery
#     188             (),
#     189         )
#     190     else:
#     191         return types.CodeType(
#     192             co.co_argcount,
#     193             co.co_kwonlyargcount,
#    (...)    206             (),
#     207         )
#
# TypeError: code() argument 13 must be str, not int
