# %%
import pandas as pd
df=pd.read_csv("/Users/samirb/Documents/GitHub/PythonRepo/src/resource/sink/student_exam_scores.csv")

# %%
df
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(5)
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %%
df.tail(3)
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 197               76        28.2
# 198               58        42.0
# 199               68        37.8

# %%
df.dtypes
# Out:
# student_id             object
# hours_studied         float64
# sleep_hours           float64
# attendance_percent    float64
# previous_scores         int64
# exam_score            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          200 non-null    object
#  1   hours_studied       200 non-null    float64
#  2   sleep_hours         200 non-null    float64
#  3   attendance_percent  200 non-null    float64
#  4   previous_scores     200 non-null    int64
#  5   exam_score          200 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 9.5+ KB

# %%
df.describe()
# Out:
#        hours_studied  sleep_hours  attendance_percent  previous_scores  \
# count     200.000000   200.000000          200.000000       200.000000
# mean        6.325500     6.622000           74.830000        66.800000
# std         3.227317     1.497138           14.249905        15.663869
# min         1.000000     4.000000           50.300000        40.000000
# 25%         3.500000     5.300000           62.200000        54.000000
# 50%         6.150000     6.700000           75.250000        67.500000
# 75%         9.000000     8.025000           87.425000        80.000000
# max        12.000000     9.000000          100.000000        95.000000
#
#        exam_score
# count  200.000000
# mean    33.955000
# std      6.789548
# min     17.100000
# 25%     29.500000
# 50%     34.050000
# 75%     38.750000
# max     51.300000

# %%
df.dtypes[df.dtypes == object]
# Out:
# student_id    object
# dtype: object

# %%
col_name=df.dtypes[df.dtypes == object].index
df[col_name].describe()
# Out:
#        student_id
# count         200
# unique        200
# top          S001
# freq            1

# %%
df['student_id'].head(3)
# Out:
# 0    S001
# 1    S002
# 2    S003
# Name: student_id, dtype: object

# %%
df.loc[[10,20]]
# Out:
#    student_id  hours_studied  sleep_hours  attendance_percent  \
# 10       S011            3.4          5.3                90.9
# 20       S021            9.9          8.8                70.7
#
#     previous_scores  exam_score
# 10               81        29.3
# 20               84        46.0

# %%
df2=df.head(5)[['student_id','previous_scores','exam_score']]
df2
# Out:
#   student_id  previous_scores  exam_score
# 0       S001               45        30.2
# 1       S002               55        25.0
# 2       S003               86        35.8
# 3       S004               66        34.0
# 4       S005               71        40.3

# %%
df3=df[5:10][['student_id','previous_scores','exam_score']]
df3
# df3.loc[9,'previous_scores']= '71'
df3.loc[9,'student_id']= 'S005'
df3
# Out:
#   student_id  previous_scores  exam_score
# 5       S006               75        35.7
# 6       S007               88        37.9
# 7       S008               55        18.3
# 8       S009               84        34.7
# 9       S005               70        24.7

# %%
pd.merge(df,df2,on='student_id')
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  \
# 0       S001            8.0          8.8                72.1
# 1       S002            1.3          8.6                60.7
# 2       S003            4.0          8.2                73.7
# 3       S004            3.5          4.8                95.1
# 4       S005            9.1          6.4                89.8
#
#    previous_scores_x  exam_score_x  previous_scores_y  exam_score_y
# 0                 45          30.2                 45          30.2
# 1                 55          25.0                 55          25.0
# 2                 86          35.8                 86          35.8
# 3                 66          34.0                 66          34.0
# 4                 71          40.3                 71          40.3
